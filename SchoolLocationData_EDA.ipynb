# %% [markdown]
# # Added Data Dictionary:

# %% [markdown]
# # Notes:
#  - 1,901 schools total
#
# Column Data:
#  - 'Census Tract' column; useful for neighborhood-level data that influences student outcomes (poverty, housing density, economic status); ensures demograhic consistency over many yrs
#  - 'Community District' column; uesful for grouping based on official governance and management units of the school system; reports to DOE use this

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# School-based information can change throughout the year. 
# Updates for the next school year are integrated into the report by July 15 of each year.

school_data = pd.read_csv('data/LCGMS_\SchoolData_20251204_1133.csv', low_memory=False)

school_data.head()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\S'
# <>:8: SyntaxWarning: invalid escape sequence '\S'
# /var/folders/1t/89rcg0rj2wvbvx9bzx26914r0000gp/T/ipykernel_75831/2675860482.py:8: SyntaxWarning: invalid escape sequence '\S'
#   school_data = pd.read_csv('data/LCGMS_\SchoolData_20251204_1133.csv', low_memory=False)
#   ATS System Code Location Code                           Location Name  \
# 0             NaN          OBIG  Intellectus Preparatory Charter School
# 1          01M015          M015               P.S. 015 Roberto Clemente
# 2          01M020          M020                    P.S. 020 Anna Silver
# 3          01M034          M034          P.S. 034 Franklin D. Roosevelt
# 4          01M063          M063               The STAR Academy - P.S.63
#
#     BEDS Number Managed By Name Location Type Description  \
# 0  6.609009e+11         Charter          General Academic
# 1  3.101000e+11             DOE          General Academic
# 2  3.101000e+11             DOE          General Academic
# 3  3.101000e+11             DOE          General Academic
# 4  3.101000e+11             DOE          General Academic
#
#   Location Category Description                            Grades  \
# 0              Secondary School              06,07,08,09,10,11,12
# 1                    Elementary           PK,0K,01,02,03,04,05,SE
# 2                    Elementary           PK,0K,01,02,03,04,05,SE
# 3                           K-8  PK,0K,01,02,03,04,05,06,07,08,SE
# 4                    Elementary           PK,0K,01,02,03,04,05,SE
#
#                     Grades Final   Open Date Status Description Building Code  \
# 0           06,07,08,09,10,11,12  Jul 1 2022               Open          OBIG
# 1           PK,0K,01,02,03,04,05  Jul 1 1904               Open          M015
# 2           PK,0K,01,02,03,04,05  Jul 1 1963               Open          M020
# 3  PK,0K,01,02,03,04,05,06,07,08  Jul 1 1955               Open          M034
# 4           PK,0K,01,02,03,04,05  Jul 1 1905               Open          M063
#
#            Primary Address          City State Code    Zip  Borough Block Lot  \
# 0  11 West Prospect Avenue  Mount Vernon         NY  10550                NaN
# 1        333 EAST 4 STREET     MANHATTAN         NY  10009       1.003740e+09
# 2         166 ESSEX STREET     MANHATTAN         NY  10002       1.003550e+09
# 3       730 East 12 Street     Manhattan         NY  10009       1.003810e+09
# 4        121 EAST 3 STREET     MANHATTAN         NY  10009       1.004310e+09
#
#    Census Tract  Community District  Council District   NTA         NTA_Name  \
# 0           NaN                 NaN               NaN   NaN              NaN
# 1        2601.0               103.0               2.0  MN28  Lower East Side
# 2        3001.0               103.0               1.0  MN27        Chinatown
# 3        2800.0               103.0               2.0  MN28  Lower East Side
# 4        3200.0               103.0               2.0  MN22     East Village
#
#    Principal Name Principal Title Principal Phone Number    Fax Number  \
# 0             NaN             NaN                    NaN           NaN
# 1   IRENE SANCHEZ       Principal           212-228-8730  212-477-0931
# 2     SARAH PINTO       Principal           212-254-9577  212-254-3526
# 3   ERICK SANCHEZ  I.A. Principal           212-228-4433  212-353-1973
# 4  David Gonzalez       Principal           212-674-3180  212-420-9018
#
#    Geographical District Code  Administrative District Code  \
# 0                           0                            84
# 1                           1                             1
# 2                           1                             1
# 3                           1                             1
# 4                           1                             1
#
#   Administrative District Location Code  Administrative District Name  \
# 0                                   NaN     OFFICE OF CHARTER SCHOOLS
# 1                                  M801  COMMUNITY SCHOOL DISTRICT 01
# 2                                  M801  COMMUNITY SCHOOL DISTRICT 01
# 3                                  M801  COMMUNITY SCHOOL DISTRICT 01
# 4                                  M801  COMMUNITY SCHOOL DISTRICT 01
#
#   Community School Sup Name HighSchool Network Location Code  \
# 0                       NaN                              NaN
# 1               CHAN, CARRY                              NaN
# 2               CHAN, CARRY                              NaN
# 3               CHAN, CARRY                              NaN
# 4               CHAN, CARRY                              NaN
#
#   HighSchool Network Name HighSchool Network Superintendent  \
# 0                     NaN                               NaN
# 1                     NaN                               NaN
# 2                     NaN                               NaN
# 3                     NaN                               NaN
# 4                     NaN                               NaN
#
#   HighSchool Network Superintendent Email BCO Location Code
# 0                                     NaN               NaN
# 1                                     NaN              MFSC
# 2                                     NaN              MFSC
# 3                                     NaN              MFSC
# 4                                     NaN              MFSC

# %%
school_data_add = pd.read_csv('extraneous_data/LCGMS_SchoolData_additional_geocoded_fields_added_ (1).csv', low_memory=False)

school_data_add.head()
# Out:
#   ATS System Code Location Code  \
# 0             NaN          O001
# 1             NaN          OAQK
# 2             NaN          OAWF
# 3          01M015          M015
# 4          01M019          M019
#
#                                        Location Name   BEDS Number  \
# 0                               Amani Charter School  6.610000e+11
# 1  Victory Schools, DBA The Charter School of Exc...  6.620000e+11
# 2                         The Academy Charter School  8.000000e+11
# 3                          P.S. 015 Roberto Clemente  3.100000e+11
# 4                                P.S. 019 Asher Levy  3.100000e+11
#
#   Managed By Name Location Type Description Location Category Description  \
# 0         Charter          General Academic              Secondary School
# 1         Charter          General Academic                    Elementary
# 2         Charter          General Academic                    Elementary
# 3             DOE          General Academic                    Elementary
# 4             DOE          General Academic                    Elementary
#
#                     Grades          Grades Final    Open Date  \
# 0                    05,06                   NaN  Dec 12 2012
# 1           0K,01,02,03,04                   NaN  Mar 20 2006
# 2        0K,01,02,03,04,05                   NaN  Jul  1 2009
# 3  PK,0K,01,02,03,04,05,SE  PK,0K,01,02,03,04,05  Jul  1 1904
# 4  PK,0K,01,02,03,04,05,SE  PK,0K,01,02,03,04,05  Jul  1 1956
#
#   Status Description Building Code          Primary Address       City  \
# 0               Open          OABQ  261 EAST LINCOLN AVENUE  MT VERNON
# 1               Open          OAQK        260 WARBURTON AVE    YONKERS
# 2               Open          OAWF         94 Fulton Avenue  Hempstead
# 3               Open          M015       333 EAST  4 STREET  MANHATTAN
# 4               Open          M019             185 1 AVENUE  MANHATTAN
#
#   State Code    Zip  Borough Block Lot  Census Tract  Community District  \
# 0         NY  10522                  0           NaN                   0
# 1         NY  10701                  0           NaN                   0
# 2         NY  11550                  0           NaN                   0
# 3         NY  10009         1003740020        2601.0                 103
# 4         NY  10003         1004530034        4000.0                 103
#
#    Council District   NTA         NTA_Name       Principal Name  \
# 0                 0   NaN              NaN                  NaN
# 1                 0   NaN              NaN                  NaN
# 2                 0   NaN              NaN                  NaN
# 3                 2  MN28  Lower East Side        IRENE SANCHEZ
# 4                 2  MN22     East Village  JACQUELINE FLANAGAN
#
#   Principal Title Principal Phone Number    Fax Number  \
# 0             NaN           914-668-6450           NaN
# 1       PRINCIPAL                    NaN           NaN
# 2             NaN                    NaN           NaN
# 3       PRINCIPAL           212-228-8730  212-477-0931
# 4       PRINCIPAL           212-533-5340  212-673-1477
#
#    Geographical District Code  Administrative District Code  \
# 0                           0                            84
# 1                           0                             0
# 2                           0                            84
# 3                           1                             1
# 4                           1                             1
#
#   Administrative District Location Code  Administrative District Name  \
# 0                                   NaN     OFFICE OF CHARTER SCHOOLS
# 1                                   NaN                OUTSIDE N.Y.C.
# 2                                   NaN     OFFICE OF CHARTER SCHOOLS
# 3                                  M801  COMMUNITY SCHOOL DISTRICT 01
# 4                                  M801  COMMUNITY SCHOOL DISTRICT 01
#
#        Superintendent Superintendent Location Code Community School Sup Name  \
# 0                 NaN                          NaN                       NaN
# 1                 NaN                          NaN                       NaN
# 2                 NaN                          NaN                       NaN
# 3  PHILLIPS, DANIELLA                         M801        PHILLIPS, DANIELLA
# 4  PHILLIPS, DANIELLA                         M801        PHILLIPS, DANIELLA
#
#   BFSC Location Code BFSC Director Name     BFSC Director Title  \
# 0                NaN                NaN                     NaN
# 1                NaN                NaN                     NaN
# 2                NaN                NaN                     NaN
# 3               MFSC          CHU, YUET  FSC Executive Director
# 4               MFSC          CHU, YUET  FSC Executive Director
#
#   BFSC Director Phone HighSchool Network Location Code  \
# 0                 NaN                              NaN
# 1                 NaN                              NaN
# 2                 NaN                              NaN
# 3        646-470-0721                              NaN
# 4        646-470-0721                              NaN
#
#   HighSchool Network Name HighSchool Network Superintendent    Borough  \
# 0                     NaN                               NaN        NaN
# 1                     NaN                               NaN        NaN
# 2                     NaN                               NaN        NaN
# 3                     NaN                               NaN  MANHATTAN
# 4                     NaN                               NaN  MANHATTAN
#
#        BIN   Latitude  Longitude
# 0      NaN        NaN        NaN
# 1      NaN        NaN        NaN
# 2      NaN        NaN        NaN
# 3           40.721807 -73.979022
# 4           40.729636 -73.983818

# %%
school_data.shape
# Out:
# (1901, 36)

# %%
school_data_add.shape
# Out:
# (1843, 44)

# %% [markdown]
# # Note:
# - 'Location Name' fewer < than 'Location Code', upon filtering
# - Suggests some Location Names are associated with the same Code (maybe elementary vs JR high vs HS names?)
# -
# - school_data has more row data, but school_data_add has additional columns (*figure out what additional ones exist here*)

# %%
school_data[school_data['Location Name'].isin(school_data_add['Location Name'])].shape
# Out:
# (1618, 36)

# %%
school_data_add[school_data_add['Location Code'].isin(school_data['Location Code'])].shape
# Out:
# (1776, 44)

# %%
common_cols = school_data.columns.intersection(school_data_add.columns)

add_cols = school_data_add.columns.difference(school_data.columns)

main_cols = school_data.columns.difference(school_data_add.columns)

print('Column names in common:\n', common_cols, '\n')
print('Columns only in school_data:\n', main_cols, '\n')
print('Columns only in school_data_add:\n', add_cols)
# Out:
# Column names in common:
#  Index(['ATS System Code', 'Location Code', 'Location Name', 'BEDS Number',
#        'Managed By Name', 'Location Type Description',
#        'Location Category Description', 'Grades', 'Grades Final', 'Open Date',
#        'Status Description', 'Building Code', 'Primary Address', 'City',
#        'State Code', 'Zip', 'Borough Block Lot', 'Census Tract',
#        'Community District', 'Council District', 'NTA', 'NTA_Name',
#        'Principal Name', 'Principal Title', 'Principal Phone Number',
#        'Fax Number', 'Geographical District Code',
#        'Administrative District Code', 'Administrative District Location Code',
#        'Administrative District Name', 'Community School Sup Name',
#        'HighSchool Network Location Code', 'HighSchool Network Name',
#        'HighSchool Network Superintendent'],
#       dtype='object')
#
# Columns only in school_data:
#  Index(['BCO Location Code', 'HighSchool Network Superintendent Email'], dtype='object')
#
# Columns only in school_data_add:
#  Index(['BFSC Director Name', 'BFSC Director Phone', 'BFSC Director Title',
#        'BFSC Location Code', 'BIN', 'Borough', 'Latitude', 'Longitude',
#        'Superintendent', 'Superintendent Location Code'],
#       dtype='object')

# %%
for col in common_cols:
    print(col)
# Out:
# ATS System Code
# Location Code
# Location Name
# BEDS Number
# Managed By Name
# Location Type Description
# Location Category Description
# Grades
# Grades Final
# Open Date
# Status Description
# Building Code
# Primary Address
# City
# State Code
# Zip
# Borough Block Lot
# Census Tract
# Community District
# Council District
# NTA
# NTA_Name
# Principal Name
# Principal Title
# Principal Phone Number
# Fax Number
# Geographical District Code
# Administrative District Code
# Administrative District Location Code
# Administrative District Name
# Community School Sup Name
# HighSchool Network Location Code
# HighSchool Network Name
# HighSchool Network Superintendent

# %%
for col in main_cols:
    print(col)
# Out:
# BCO Location Code
# HighSchool Network Superintendent Email

# %%
for col in add_cols:
    print(col)
# Out:
# BFSC Director Name
# BFSC Director Phone
# BFSC Director Title
# BFSC Location Code
# BIN
# Borough
# Latitude
# Longitude
# Superintendent
# Superintendent Location Code

# %%
school_data.sample()
# Out:
#      ATS System Code Location Code                   Location Name  \
# 1632          84K536          K536  Community Roots Charter School
#
#        BEDS Number Managed By Name Location Type Description  \
# 1632  3.313009e+11         Charter          General Academic
#
#      Location Category Description                         Grades  \
# 1632                           K-8  0K,01,02,03,04,05,06,07,08,SE
#
#                     Grades Final   Open Date Status Description Building Code  \
# 1632  0K,01,02,03,04,05,06,07,08  Jul 1 2006               Open          K067
#
#               Primary Address      City State Code    Zip  Borough Block Lot  \
# 1632  51 SAINT EDWARDS STREET  BROOKLYN         NY  11205       3.020390e+09
#
#       Census Tract  Community District  Council District   NTA     NTA_Name  \
# 1632        2901.0               302.0              35.0  BK68  Fort Greene
#
#                Principal Name Principal Title Principal Phone Number  \
# 1632  Allison Keil/Sara Stone       Principal           718-858-1629
#
#         Fax Number  Geographical District Code  Administrative District Code  \
# 1632  718-858-1754                          13                            84
#
#      Administrative District Location Code Administrative District Name  \
# 1632                                   NaN    OFFICE OF CHARTER SCHOOLS
#
#      Community School Sup Name HighSchool Network Location Code  \
# 1632                       NaN                              NaN
#
#      HighSchool Network Name HighSchool Network Superintendent  \
# 1632                     NaN                               NaN
#
#      HighSchool Network Superintendent Email BCO Location Code
# 1632                                     NaN               NaN

# %% [markdown]
# # Note:
# - Location Name 'HBCU Early College Prep HS' is missing!
# - Was just opened this Fall, 2025

# %%
school_data[school_data['Location Name'] == 'Northwell School of Health Sciences']
# Out:
#      ATS System Code Location Code                        Location Name  \
# 1443          30Q472          Q472  Northwell School of Health Sciences
#
#        BEDS Number Managed By Name Location Type Description  \
# 1443  3.430000e+11             DOE          General Academic
#
#      Location Category Description Grades    Grades Final   Open Date  \
# 1443                   High school  09,SE  09,10,11,12,SE  Jul 1 2025
#
#      Status Description Building Code           Primary Address    City  \
# 1443               Open          Q472  53-16 Northern Boulevard  Queens
#
#      State Code    Zip  Borough Block Lot  Census Tract  Community District  \
# 1443         NY  11377       4.011920e+09         255.0               402.0
#
#       Council District   NTA  NTA_Name Principal Name Principal Title  \
# 1443              26.0  QN63  Woodside  Erika Hurtado       Principal
#
#      Principal Phone Number Fax Number  Geographical District Code  \
# 1443                    NaN        NaN                          30
#
#       Administrative District Code Administrative District Location Code  \
# 1443                            30                                  HS03
#
#      Administrative District Name Community School Sup Name  \
# 1443                          NaN                       NaN
#
#      HighSchool Network Location Code              HighSchool Network Name  \
# 1443                             HS03  HS Network 03 Superintendent Office
#
#      HighSchool Network Superintendent  \
# 1443                       WALSH, FRED
#
#      HighSchool Network Superintendent Email BCO Location Code
# 1443                  FWalsh@schools.nyc.gov              MFSC

# %%
school_data_add[school_data_add['Location Name'] == 'Northwell School of Health Sciences']
# Out:
# Empty DataFrame
# Columns: [ATS System Code, Location Code, Location Name, BEDS Number, Managed By Name, Location Type Description, Location Category Description, Grades, Grades Final, Open Date, Status Description, Building Code, Primary Address, City, State Code, Zip, Borough Block Lot, Census Tract, Community District, Council District, NTA, NTA_Name, Principal Name, Principal Title, Principal Phone Number, Fax Number, Geographical District Code, Administrative District Code, Administrative District Location Code, Administrative District Name, Superintendent, Superintendent Location Code, Community School Sup Name, BFSC Location Code, BFSC Director Name, BFSC Director Title, BFSC Director Phone, HighSchool Network Location Code, HighSchool Network Name, HighSchool Network Superintendent, Borough, BIN, Latitude, Longitude]
# Index: []

# %%
school_data[school_data['Location Code'] == 'K084']
# Out:
#     ATS System Code Location Code           Location Name   BEDS Number  \
# 694          14K084          K084  P.S. 084 Jose De Diego  3.314000e+11
#
#     Managed By Name Location Type Description Location Category Description  \
# 694             DOE          General Academic                           K-8
#
#                                Grades                   Grades Final  \
# 694  PK,0K,01,02,03,04,05,06,07,08,SE  PK,0K,01,02,03,04,05,06,07,08
#
#       Open Date Status Description Building Code   Primary Address      City  \
# 694  Jul 1 1969               Open          K084  250 Berry Street  Brooklyn
#
#     State Code    Zip  Borough Block Lot  Census Tract  Community District  \
# 694         NY  11249       3.023910e+09       55100.0               301.0
#
#      Council District   NTA               NTA_Name     Principal Name  \
# 694              34.0  BK73  North Side-South Side  Sereida Rodriguez
#
#     Principal Title Principal Phone Number    Fax Number  \
# 694       Principal           718-384-8063  718-302-2313
#
#      Geographical District Code  Administrative District Code  \
# 694                          14                            14
#
#     Administrative District Location Code  Administrative District Name  \
# 694                                  K814  COMMUNITY SCHOOL DISTRICT 14
#
#     Community School Sup Name HighSchool Network Location Code  \
# 694             DAVID CINTRON                              NaN
#
#     HighSchool Network Name HighSchool Network Superintendent  \
# 694                     NaN                               NaN
#
#     HighSchool Network Superintendent Email BCO Location Code
# 694                                     NaN              KFSN

# %%
school_data[school_data['Zip'] == 11368]
# Out:
#      ATS System Code Location Code  \
# 1096          24Q014          Q014
# 1097          24Q016          Q016
# 1098          24Q019          Q019
# 1099          24Q028          Q028
# 1102          24Q061          Q061
# 1114          24Q110          Q110
# 1119          24Q143          Q143
# 1122          24Q211          Q211
# 1133          24Q307          Q307
# 1134          24Q311          Q311
# 1135          24Q330          Q330
# 1143          24Q550          Q550
# 1404          30Q092          Q092
# 1782          84Q418          Q418
#
#                                           Location Name   BEDS Number  \
# 1096                                  P.S. 014 Fairview  3.424000e+11
# 1097            P.S. Q016 The Nancy DeBenedittis School  3.424000e+11
# 1098                            P.S. 019 Marino Jeantet  3.424000e+11
# 1099  P.S. 28 - The Thomas Emanuel Early Childhood C...  3.424000e+11
# 1102                         I.S. 061 Leonardo Da Vinci  3.424000e+11
# 1114                                           P.S. 110  3.424000e+11
# 1119                           P.S. 143 Louis Armstrong  3.424000e+11
# 1122                         Elm Tree Elementary School  3.424000e+11
# 1133                                    Pioneer Academy  3.424000e+11
# 1134                     Corona Arts & Sciences Academy  3.424000e+11
# 1135                           Helen M. Marshall School  3.424000e+11
# 1143                  High School for Arts and Business  3.424000e+11
# 1404                      P.S. 092 Harry T. Stewart Sr.  3.430000e+11
# 1782            Our World Neighborhood Charter School 3  3.424009e+11
#
#      Managed By Name Location Type Description  \
# 1096             DOE          General Academic
# 1097             DOE          General Academic
# 1098             DOE          General Academic
# 1099             DOE          General Academic
# 1102             DOE          General Academic
# 1114             DOE          General Academic
# 1119             DOE          General Academic
# 1122             DOE          General Academic
# 1133             DOE          General Academic
# 1134             DOE          General Academic
# 1135             DOE          General Academic
# 1143             DOE          General Academic
# 1404             DOE          General Academic
# 1782         Charter          General Academic
#
#         Location Category Description                   Grades  \
# 1096                       Elementary     0K,01,02,03,04,05,SE
# 1097                       Elementary     0K,01,02,03,04,05,SE
# 1098                       Elementary  PK,0K,01,02,03,04,05,SE
# 1099                  Early Childhood              0K,01,02,SE
# 1102  Junior High-Intermediate-Middle              06,07,08,SE
# 1114                       Elementary     0K,01,02,03,04,05,SE
# 1119                       Elementary  PK,0K,01,02,03,04,05,SE
# 1122                       Elementary  PK,0K,01,02,03,04,05,SE
# 1133                       Elementary  PK,0K,01,02,03,04,05,SE
# 1134  Junior High-Intermediate-Middle              06,07,08,SE
# 1135                       Elementary     0K,01,02,03,04,05,SE
# 1143                      High school           09,10,11,12,SE
# 1404                       Elementary  PK,0K,01,02,03,04,05,SE
# 1782                       Elementary           0K,01,02,03,04
#
#               Grades Final    Open Date Status Description Building Code  \
# 1096     0K,01,02,03,04,05   Jul 1 1915               Open          Q014
# 1097     0K,01,02,03,04,05   Jul 1 1999               Open          Q721
# 1098     0K,01,02,03,04,05   Jul 1 1924               Open          Q019
# 1099           PK,0K,01,02   Jul 1 2002               Open          Q028
# 1102              06,07,08   Jul 1 1966               Open          Q061
# 1114     0K,01,02,03,04,05   Jul 1 2012               Open          Q315
# 1119     0K,01,02,03,04,05   Jul 1 1929               Open          Q143
# 1122     0K,01,02,03,04,05   Jul 1 2013               Open          Q298
# 1133  PK,0K,01,02,03,04,05   Jul 1 2008               Open          Q260
# 1134              06,07,08   Jul 1 2013               Open          Q311
# 1135     0K,01,02,03,04,05   Jul 1 2010               Open          Q287
# 1143           09,10,11,12  Apr 24 1998               Open          Q456
# 1404  PK,0K,01,02,03,04,05   Jul 1 1913               Open          Q292
# 1782                   NaN   Jul 1 2022               Open          QCQV
#
#                    Primary Address    City State Code    Zip  \
# 1096            107-01 OTIS AVENUE  QUEENS         NY  11368
# 1097              41-15 104 STREET  QUEENS         NY  11368
# 1098               40-10 99 Street  Queens         NY  11368
# 1099              109-10 47 AVENUE  QUEENS         NY  11368
# 1102               98-50 50 AVENUE  QUEENS         NY  11368
# 1114                43-18 97 Place  Queens         NY  11368
# 1119              34-55 112 Street  Queens         NY  11368
# 1122               50-51 98 Street  Queens         NY  11368
# 1133              40-20 100 Street  Queens         NY  11368
# 1134               98-11 44 Avenue  Queens         NY  11368
# 1135     110-08 NORTHERN BOULEVARD  QUEENS         NY  11368
# 1143  105-25 Horace Harding Expy N  Queens         NY  11368
# 1404               99-01 34 AVENUE  QUEENS         NY  11368
# 1782       108-68 Roosevelt Avenue  Queens         NY  11368
#
#       Borough Block Lot  Census Tract  Community District  Council District  \
# 1096       4.019540e+09       43900.0               404.0              21.0
# 1097       4.019850e+09       40300.0               404.0              21.0
# 1098       4.016070e+09       40900.0               404.0              21.0
# 1099       4.020030e+09       41500.0               404.0              21.0
# 1102       4.018910e+09       44302.0               404.0              21.0
# 1114       4.016130e+09       37500.0               404.0              21.0
# 1119       4.017560e+09       38100.0               403.0              21.0
# 1122       4.018910e+09       44302.0               404.0              21.0
# 1133       4.016080e+09       40700.0               404.0              21.0
# 1134       4.016280e+09       40900.0               404.0              21.0
# 1135       4.017250e+09       38100.0               403.0              21.0
# 1143       4.019630e+09       43701.0               404.0              21.0
# 1404       4.017140e+09       37700.0               403.0              21.0
# 1782       4.019968e+09        2003.0               404.0              21.0
#
#        NTA      NTA_Name       Principal Name Principal Title  \
# 1096  QN25        Corona       Heather Benson       Principal
# 1097  QN26  North Corona  Katherine Rodriguez  I.A. Principal
# 1098  QN26  North Corona      KRYSTLE JIMENEZ       Principal
# 1099  QN25        Corona      Robert Quintana       Principal
# 1102  QN25        Corona          JOSEPH LISA       Principal
# 1114  QN26  North Corona          Elisa Gomez       Principal
# 1119  QN26  North Corona        Justine Lucas       Principal
# 1122  QN25        Corona        Kristen Niven       Principal
# 1133  QN26  North Corona      CECILIA JACKSON       Principal
# 1134  QN26  North Corona            Beth Hert       Principal
# 1135  QN26  North Corona        Debra Rudolph       Principal
# 1143  QN25        Corona  ANA ZAMBRANO BURAKO       Principal
# 1404  QN26  North Corona        Daisy Morales       Principal
# 1782   NaN           NaN       Tanicqua Pryor       Principal
#
#      Principal Phone Number    Fax Number  Geographical District Code  \
# 1096           718-699-6071  718-699-3224                          24
# 1097           718-505-0140  718-505-0141                          24
# 1098           718-424-5859  718-424-7953                          24
# 1099           718-271-4971  718-271-2576                          24
# 1102           718-760-3233  718-760-5220                          24
# 1114           718-424-8278  718-424-8345                          24
# 1119           718-429-5700  718-478-8306                          24
# 1122           929-208-4860  909-208-4862                          24
# 1133           718-779-5068  718-779-5109                          24
# 1134           718-507-3820  718-507-3828                          24
# 1135           718-505-5110  718-505-5115                          24
# 1143           718-271-8383  718-271-7196                          24
# 1404           718-533-1013  718-533-1083                          30
# 1782                    NaN           NaN                          24
#
#       Administrative District Code Administrative District Location Code  \
# 1096                            24                                  Q824
# 1097                            24                                  Q824
# 1098                            24                                  Q824
# 1099                            24                                  Q824
# 1102                            24                                  Q824
# 1114                            24                                  Q824
# 1119                            24                                  Q824
# 1122                            24                                  Q824
# 1133                            24                                  Q824
# 1134                            24                                  Q824
# 1135                            24                                  Q824
# 1143                            24                                  HS01
# 1404                            30                                  Q830
# 1782                            84                                   NaN
#
#       Administrative District Name Community School Sup Name  \
# 1096  COMMUNITY SCHOOL DISTRICT 24            ANTHONY RIVERA
# 1097  COMMUNITY SCHOOL DISTRICT 24            ANTHONY RIVERA
# 1098  COMMUNITY SCHOOL DISTRICT 24            ANTHONY RIVERA
# 1099  COMMUNITY SCHOOL DISTRICT 24            ANTHONY RIVERA
# 1102  COMMUNITY SCHOOL DISTRICT 24            ANTHONY RIVERA
# 1114  COMMUNITY SCHOOL DISTRICT 24            ANTHONY RIVERA
# 1119  COMMUNITY SCHOOL DISTRICT 24            ANTHONY RIVERA
# 1122  COMMUNITY SCHOOL DISTRICT 24            ANTHONY RIVERA
# 1133  COMMUNITY SCHOOL DISTRICT 24            ANTHONY RIVERA
# 1134  COMMUNITY SCHOOL DISTRICT 24            ANTHONY RIVERA
# 1135  COMMUNITY SCHOOL DISTRICT 24            ANTHONY RIVERA
# 1143                           NaN                       NaN
# 1404  COMMUNITY SCHOOL DISTRICT 30              LISA HIDALGO
# 1782     OFFICE OF CHARTER SCHOOLS                       NaN
#
#      HighSchool Network Location Code              HighSchool Network Name  \
# 1096                              NaN                                  NaN
# 1097                              NaN                                  NaN
# 1098                              NaN                                  NaN
# 1099                              NaN                                  NaN
# 1102                              NaN                                  NaN
# 1114                              NaN                                  NaN
# 1119                              NaN                                  NaN
# 1122                              NaN                                  NaN
# 1133                              NaN                                  NaN
# 1134                              NaN                                  NaN
# 1135                              NaN                                  NaN
# 1143                             HS01  HS Network 01 Superintendent Office
# 1404                              NaN                                  NaN
# 1782                              NaN                                  NaN
#
#      HighSchool Network Superintendent  \
# 1096                               NaN
# 1097                               NaN
# 1098                               NaN
# 1099                               NaN
# 1102                               NaN
# 1114                               NaN
# 1119                               NaN
# 1122                               NaN
# 1133                               NaN
# 1134                               NaN
# 1135                               NaN
# 1143                            HOA TU
# 1404                               NaN
# 1782                               NaN
#
#      HighSchool Network Superintendent Email BCO Location Code
# 1096                                     NaN              QFSN
# 1097                                     NaN              QFSN
# 1098                                     NaN              QFSN
# 1099                                     NaN              QFSN
# 1102                                     NaN              QFSN
# 1114                                     NaN              QFSN
# 1119                                     NaN              QFSN
# 1122                                     NaN              QFSN
# 1133                                     NaN              QFSN
# 1134                                     NaN              QFSN
# 1135                                     NaN              QFSN
# 1143                     htu@schools.nyc.gov              QFSN
# 1404                                     NaN              QFSN
# 1782                                     NaN               NaN

# %%
school_data['Community District'].value_counts().shape
# Out:
# (60,)
