# %% [markdown]
# # MTA On-Time Performance EDA
#
# ## Data Dictionary:
# - https://data.ny.gov/Transportation/MTA-Subway-Terminal-On-Time-Performance-2015-2019/f6rf-2a3t/about_data
# - https://data.ny.gov/Transportation/MTA-Subway-Terminal-On-Time-Performance-2020-2024/vtvh-gimj/about_data

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

mta_time_1 = pd.read_csv('../data/MTA_Subway_Terminal_On-Time_Performance_2015-2019.csv', low_memory=False)
mta_time_2 = pd.read_csv('../data/MTA_Subway_Terminal_On-Time_Performance_2020-2024.csv', low_memory=False)

mta_time_1.sample(5)
# Out:
#            month    division    line  day_type num_on_time_trips  \
# 579   2017-02-01  A DIVISION       2         1             1,648
# 1061  2018-10-01  B DIVISION       A         1             4,579
# 1106  2018-12-01  A DIVISION  S 42nd         1            12,209
# 1194  2019-04-01  A DIVISION       2         2             1,022
# 569   2017-01-01  B DIVISION      JZ         1             3,717
#
#      num_sched_trips terminal_on_time_performance
# 579            6,030                  27.3300166%
# 1061           8,482                  53.9849092%
# 1106          12,234                  99.7956515%
# 1194           1,900                  53.7894737%
# 569            5,859                  63.4408602%

# %%
mta_time_1[mta_time_1['line'] == 'J'].head()
# Out:
# Empty DataFrame
# Columns: [month, division, line, day_type, num_on_time_trips, num_sched_trips, terminal_on_time_performance]
# Index: []

# %%
mta_time_1['line'].value_counts()
# Out:
# line
# 1         69
# 2         69
# S Rock    69
# S Fkln    69
# R         69
# Q         69
# N         69
# M         69
# L         69
# JZ        69
# G         69
# F         69
# E         69
# D         69
# C         69
# A         69
# S 42nd    69
# 7         69
# 6         69
# 5         69
# 4         69
# 3         69
# B         60
# W         18
# Name: count, dtype: int64

# %%
mta_time_2.sample(5)
# Out:
#            month    division line  day_type num_on_time_trips num_sched_trips  \
# 2639  2020-02-01  B DIVISION    R         1             4,209           5,343
# 1389  2022-06-01  B DIVISION    N         1             7,634           9,759
# 1449  2022-04-01  A DIVISION    5         1             5,665           6,860
# 405   2024-03-01  A DIVISION    1         1             7,600           9,602
# 2193  2020-12-01  B DIVISION    J         2             1,827           2,004
#
#      terminal_on_time_performance
# 2639                   78.775966%
# 1389                   78.225225%
# 1449                   82.580173%
# 405                    79.150176%
# 2193                   91.167665%

# %%
mta_time_2['line'].value_counts()
# Out:
# line
# 1         120
# D         120
# R         120
# Q         120
# N         120
# M         120
# L         120
# 2         120
# F         120
# E         120
# G         120
# 7         120
# 6         120
# 5         120
# 4         120
# 3         120
# A         119
# C         118
# FS        112
# H         112
# J         112
# GS        103
# B          58
# JZ          8
# S 42nd      8
# S Fkln      8
# S Rock      8
# Name: count, dtype: int64

# %%
mta_time_2[mta_time_2['line'] == 'JZ'].head()
# Out:
#           month    division line  day_type num_on_time_trips num_sched_trips  \
# 27   2024-12-01  B DIVISION   JZ         2             2,242           2,432
# 28   2024-12-01  B DIVISION   JZ         1             5,265           6,251
# 72   2024-11-01  B DIVISION   JZ         1             4,767           5,984
# 73   2024-11-01  B DIVISION   JZ         2             2,220           2,460
# 117  2024-10-01  B DIVISION   JZ         2             1,416           1,528
#
#     terminal_on_time_performance
# 27                      92.1875%
# 28                    84.226525%
# 72                     79.66243%
# 73                      90.2439%
# 117                   92.670155%

# %%
mta_time_2[mta_time_2['line'] == 'J'].head()
# Out:
#           month    division line  day_type num_on_time_trips num_sched_trips  \
# 213  2024-08-01  B DIVISION    J         1             5,348           6,582
# 214  2024-08-01  B DIVISION    J         2             1,975           2,132
# 258  2024-07-01  B DIVISION    J         2             2,011           2,228
# 259  2024-07-01  B DIVISION    J         1             4,963           6,281
# 303  2024-06-01  B DIVISION    J         1             4,722           5,582
#
#     terminal_on_time_performance
# 213                     81.2519%
# 214                   92.636025%
# 258                    90.26032%
# 259                    79.01608%
# 303                    84.59334%

# %%
mta_time_1.shape
# Out:
# (1596, 7)

# %%
mta_time_2.shape
# Out:
# (2686, 7)

# %%
mta_time_1[10:20]
# Out:
#          month    division line  day_type num_on_time_trips num_sched_trips  \
# 10  2015-01-01  B DIVISION    C         1             3,359           4,000
# 11  2015-01-01  B DIVISION    D         1             4,022           5,288
# 12  2015-01-01  B DIVISION    E         1             5,453           7,894
# 13  2015-01-01  B DIVISION    F         1             4,597           7,939
# 14  2015-01-01  B DIVISION    G         1             3,961           5,664
# 15  2015-01-01  B DIVISION   JZ         1             4,374           5,444
# 16  2015-01-01  B DIVISION    L         1             9,109           9,808
# 17  2015-01-01  B DIVISION    M         1             3,761           5,315
# 18  2015-01-01  B DIVISION    N         1             3,601           5,259
# 19  2015-01-01  B DIVISION    Q         1             3,737           5,348
#
#    terminal_on_time_performance
# 10                      83.975%
# 11                  76.0590015%
# 12                  69.0777806%
# 13                  57.9040181%
# 14                  69.9329096%
# 15                  80.3453343%
# 16                  92.8731648%
# 17                  70.7619944%
# 18                  68.4730937%
# 19                  69.8765894%

# %% [markdown]
# # Note:
# - From 2015-2019 (mta_time_1) there is no J line distinction, only JZ
# - From 2020 onward (mta_time_2) there ARE line distinctions: J and JZ lines
# - FS and GS line distinction are also introduced in 2020
# - ALSO, H line introduced in 2020 (H = legacy label for 'Rockaway Park Shuttle')
#
# ## Converting S Fkln -> FS and S 42nd to GS:
# - And S Rock -> RS
# - And H -> RS

# %%
mta_time_1['line'] = mta_time_1['line'].apply(lambda line: 'FS' if line == 'S Fkln' else 'GS' if line == 'S 42nd' else 'RS' if line == 'S Rock' else line)
mta_time_2['line'] = mta_time_2['line'].apply(lambda line: 'FS' if line == 'S Fkln' else 'GS' if line == 'S 42nd' else 'RS' if (line == 'S Rock' or line == 'H') else line)

# %%
# Combining the two datasets:
mta_time_df = pd.concat([mta_time_1, mta_time_2], ignore_index=True)

mta_time_df.shape
# Out:
# (4282, 7)

# %%
mta_time_df.sample(10)
# Out:
#            month    division line  day_type num_on_time_trips num_sched_trips  \
# 1363  2019-07-01  B DIVISION    Q         1             5,978           6,931
# 1145  2019-02-01  A DIVISION    1         1             7,336           8,778
# 451   2016-08-01  B DIVISION    G         1             5,352           6,478
# 1606  2024-12-01  A DIVISION    6         1             9,797          11,740
# 1040  2018-09-01  B DIVISION    C         1             2,311           3,799
# 520   2016-11-01  B DIVISION    G         1             4,434           5,880
# 951   2018-05-01  B DIVISION    F         1             3,414           8,508
# 300   2016-02-01  A DIVISION    2         1             2,503           6,264
# 1156  2019-02-01  B DIVISION    D         1             2,948           5,234
# 2323  2023-08-01  A DIVISION    4         2             1,791           2,136
#
#      terminal_on_time_performance
# 1363                  86.2501803%
# 1145                  83.5725678%
# 451                    82.618092%
# 1606                   83.449745%
# 1040                  60.8317978%
# 520                   75.4081633%
# 951                   40.1269394%
# 300                    39.958493%
# 1156                  56.3240352%
# 2323                   83.848315%

# %%
mta_time_df['line'].value_counts(sort=False)
# Out:
# line
# 1     189
# 2     189
# 3     189
# 4     189
# 5     189
# 6     189
# 7     189
# GS    180
# A     188
# B     118
# C     187
# D     189
# E     189
# F     189
# G     189
# JZ     77
# L     189
# M     189
# N     189
# Q     189
# R     189
# FS    189
# RS    189
# W      18
# J     112
# Name: count, dtype: int64

# %%
len(mta_time_df['line'].unique())
# Out:
# 25

# %%
JZ_df = mta_time_df[mta_time_df['line'] == 'JZ']
J_df = mta_time_df[mta_time_df['line'] == 'J']

JZ_df.head()
# Out:
#           month    division line  day_type num_on_time_trips num_sched_trips  \
# 15   2015-01-01  B DIVISION   JZ         1             4,374           5,444
# 38   2015-02-01  B DIVISION   JZ         1             3,750           5,193
# 61   2015-03-01  B DIVISION   JZ         1             4,816           5,996
# 84   2015-04-01  B DIVISION   JZ         1             4,770           5,998
# 107  2015-05-01  B DIVISION   JZ         1             3,935           5,454
#
#     terminal_on_time_performance
# 15                   80.3453343%
# 38                   72.2125939%
# 61                   80.3202135%
# 84                   79.5265088%
# 107                  72.1488816%

# %%
J_df.head()
# Out:
#            month    division line  day_type num_on_time_trips num_sched_trips  \
# 1809  2024-08-01  B DIVISION    J         1             5,348           6,582
# 1810  2024-08-01  B DIVISION    J         2             1,975           2,132
# 1854  2024-07-01  B DIVISION    J         2             2,011           2,228
# 1855  2024-07-01  B DIVISION    J         1             4,963           6,281
# 1899  2024-06-01  B DIVISION    J         1             4,722           5,582
#
#      terminal_on_time_performance
# 1809                     81.2519%
# 1810                   92.636025%
# 1854                    90.26032%
# 1855                    79.01608%
# 1899                    84.59334%

# %%
JZ_df.describe()
# Out:
#         day_type
# count  77.000000
# mean    1.168831
# std     0.377059
# min     1.000000
# 25%     1.000000
# 50%     1.000000
# 75%     1.000000
# max     2.000000

# %%
J_df.describe()
# Out:
#          day_type
# count  112.000000
# mean     1.500000
# std      0.502247
# min      1.000000
# 25%      1.000000
# 50%      1.500000
# 75%      2.000000
# max      2.000000

# %% [markdown]
# ## Converting numerical data into datetimes, ints, and floats:

# %%
mta_time_df.dtypes
# Out:
# month                           object
# division                        object
# line                            object
# day_type                         int64
# num_on_time_trips               object
# num_sched_trips                 object
# terminal_on_time_performance    object
# dtype: object

# %%
# Datetime conversion:
mta_time_df['month'] = pd.to_datetime(mta_time_df['month'], format='%Y-%m-%d')

# %%
# Int conversion:
mta_time_df['num_on_time_trips'] = mta_time_df['num_on_time_trips'].apply(lambda x: int(x.replace(',', '')))
mta_time_df['num_sched_trips'] = mta_time_df['num_sched_trips'].apply(lambda x: int(x.replace(',', '')))

# %%
# Float conversion:
mta_time_df['terminal_on_time_performance'] = mta_time_df['terminal_on_time_performance'].apply(lambda x: float(x.replace('%', '')))

# %%
mta_time_df.head()
# Out:
#        month    division line  day_type  num_on_time_trips  num_sched_trips  \
# 0 2015-01-01  A DIVISION    1         1               6874             9017
# 1 2015-01-01  A DIVISION    2         1               2920             6175
# 2 2015-01-01  A DIVISION    3         1               4004             5834
# 3 2015-01-01  A DIVISION    4         1               3692             7623
# 4 2015-01-01  A DIVISION    5         1               3203             6491
#
#    terminal_on_time_performance
# 0                     76.233781
# 1                     47.287449
# 2                     68.632156
# 3                     48.432376
# 4                     49.345247

# %%
mta_time_df.dtypes
# Out:
# month                           datetime64[ns]
# division                                object
# line                                    object
# day_type                                 int64
# num_on_time_trips                        int64
# num_sched_trips                          int64
# terminal_on_time_performance           float64
# dtype: object

# %% [markdown]
# ## Creating 'Daytime Routes' column, changing JZ -> Z line data
# - NO exclusively J data between 2015 and 2019!

# %%
mta_time_df['Daytime Routes'] = mta_time_df['line'].apply(lambda line: 'Z' if line == 'JZ' else line)

mta_time_df.sample(10)
# Out:
#           month    division line  day_type  num_on_time_trips  \
# 1174 2019-03-01  A DIVISION    7         1              12046
# 639  2017-04-01  B DIVISION    F         1               3460
# 3790 2020-12-01  B DIVISION    L         1              11033
# 2190 2023-11-01  A DIVISION    5         2               1280
# 988  2018-07-01  A DIVISION    5         1               4116
# 2335 2023-08-01  B DIVISION    D         2               2787
# 2567 2023-03-01  B DIVISION   FS         1               5406
# 4170 2020-03-01  B DIVISION    F         2               1205
# 4150 2020-03-01  A DIVISION    2         2               1123
# 1665 2024-11-01  B DIVISION    F         2               1584
#
#       num_sched_trips  terminal_on_time_performance Daytime Routes
# 1174            13237                     91.002493              7
# 639              7612                     45.454546              F
# 3790            11952                     92.310910              L
# 2190             1761                     72.685975              5
# 988              6909                     59.574468              5
# 2335             2995                     93.055093              D
# 2567             5428                     99.594694             FS
# 4170             1451                     83.046174              F
# 4150             1508                     74.469495              2
# 1665             2093                     75.680840              F
