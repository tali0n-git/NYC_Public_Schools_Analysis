# %% [markdown]
# # MTA Subway Line Groupings
#
# ## Goal:
# - Group the subway stations into their respective train lines:

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

stations = pd.read_csv('../cleaned_data/MTA_Subway_Stations_With_Census_Tracts_2025.csv', low_memory=False)

stations.shape
# Out:
# (496, 9)

# %%
stations[stations['Daytime Routes'].str.contains('Z', na=False)]
# Out:
#     Daytime Routes GTFS Stop ID  Station ID  \
# 79             J Z          J12          80
# 81             J Z          J14          82
# 82             J Z          J15          83
# 84             J Z          J17          85
# 86             J Z          J20          87
# 87             J Z          J21          88
# 89             J Z          J23          90
# 90             J Z          J24          91
# 91             J Z          J27          92
# 92             J Z          J28          93
# 94             J Z          J30          95
# 96           M J Z          M11          97
# 100          M J Z          M16         101
# 101          M J Z          M18         102
# 102            J Z          M19         103
# 103            J Z          M20         104
# 104            J Z          M21         105
# 105            J Z          M22         106
# 106            J Z          M23         107
# 278          E J Z          G05         278
# 279          E J Z          G06         279
#
#                               Stop Name Borough  GTFS Latitude  \
# 79                               121 St       Q      40.700492
# 81                               104 St       Q      40.695178
# 82                       Woodhaven Blvd       Q      40.693879
# 84                     75 St-Elderts Ln       Q      40.691324
# 86                          Crescent St      Bk      40.683194
# 87                           Norwood Av      Bk      40.681410
# 89                        Van Siclen Av      Bk      40.678024
# 90                           Alabama Av      Bk      40.676992
# 91                    Broadway Junction      Bk      40.679498
# 92                          Chauncey St      Bk      40.682893
# 94                             Gates Av      Bk      40.689630
# 96                            Myrtle Av      Bk      40.697207
# 100                            Marcy Av      Bk      40.708359
# 101                Delancey St-Essex St       M      40.718315
# 102                              Bowery       M      40.720280
# 103                            Canal St       M      40.718092
# 104                         Chambers St       M      40.713243
# 105                           Fulton St       M      40.710374
# 106                            Broad St       M      40.706476
# 278       Jamaica Center-Parsons/Archer       Q      40.702147
# 279  Sutphin Blvd-Archer Av-JFK Airport       Q      40.700486
#
#      GTFS Longitude  Census Tract  Census Tract Whole
# 79       -73.828294        144.00                 144
# 81       -73.844330         26.00                  26
# 82       -73.851576         20.00                  20
# 84       -73.867139          4.00                   4
# 86       -73.873785       1178.00                1178
# 87       -73.880039       1174.00                1174
# 89       -73.891688       1198.00                1198
# 90       -73.898654       1198.00                1198
# 91       -73.904512        405.00                 405
# 92       -73.910456        369.00                 369
# 94       -73.922270        397.00                 397
# 96       -73.935657        287.00                 287
# 100      -73.957757        529.00                 529
# 101      -73.987437         18.00                  18
# 102      -73.993915         18.00                  18
# 103      -73.999892         41.00                  41
# 104      -74.003401         29.01                  29
# 105      -74.007582         15.01                  15
# 106      -74.011056          7.00                   7
# 278      -73.801109        246.00                 246
# 279      -73.807969        208.00                 208

# %% [markdown]
# # Note:
# - Z always appears with J (it is the express train w.r.t. the J train)

# %%
# Split rows into multiple rows based on 'Daytime Routes' column
stations_expanded = stations.assign(**{
    'Daytime Routes': stations['Daytime Routes'].str.split(' ')
}).explode('Daytime Routes')
stations_expanded.head()
# Out:
#   Daytime Routes GTFS Stop ID  Station ID             Stop Name Borough  \
# 0              N          R01           1  Astoria-Ditmars Blvd       Q
# 0              W          R01           1  Astoria-Ditmars Blvd       Q
# 1              N          R03           2          Astoria Blvd       Q
# 1              W          R03           2          Astoria Blvd       Q
# 2              N          R04           3                 30 Av       Q
#
#    GTFS Latitude  GTFS Longitude  Census Tract  Census Tract Whole
# 0      40.775036      -73.912034         115.0                 115
# 0      40.775036      -73.912034         115.0                 115
# 1      40.770258      -73.917843         125.0                 125
# 1      40.770258      -73.917843         125.0                 125
# 2      40.766779      -73.921479          63.0                  63

# %%
stations_expanded.shape
# Out:
# (767, 9)

# %%
stations_expanded[stations_expanded['Daytime Routes'] == 'Z']
# Out:
#     Daytime Routes GTFS Stop ID  Station ID  \
# 79               Z          J12          80
# 81               Z          J14          82
# 82               Z          J15          83
# 84               Z          J17          85
# 86               Z          J20          87
# 87               Z          J21          88
# 89               Z          J23          90
# 90               Z          J24          91
# 91               Z          J27          92
# 92               Z          J28          93
# 94               Z          J30          95
# 96               Z          M11          97
# 100              Z          M16         101
# 101              Z          M18         102
# 102              Z          M19         103
# 103              Z          M20         104
# 104              Z          M21         105
# 105              Z          M22         106
# 106              Z          M23         107
# 278              Z          G05         278
# 279              Z          G06         279
#
#                               Stop Name Borough  GTFS Latitude  \
# 79                               121 St       Q      40.700492
# 81                               104 St       Q      40.695178
# 82                       Woodhaven Blvd       Q      40.693879
# 84                     75 St-Elderts Ln       Q      40.691324
# 86                          Crescent St      Bk      40.683194
# 87                           Norwood Av      Bk      40.681410
# 89                        Van Siclen Av      Bk      40.678024
# 90                           Alabama Av      Bk      40.676992
# 91                    Broadway Junction      Bk      40.679498
# 92                          Chauncey St      Bk      40.682893
# 94                             Gates Av      Bk      40.689630
# 96                            Myrtle Av      Bk      40.697207
# 100                            Marcy Av      Bk      40.708359
# 101                Delancey St-Essex St       M      40.718315
# 102                              Bowery       M      40.720280
# 103                            Canal St       M      40.718092
# 104                         Chambers St       M      40.713243
# 105                           Fulton St       M      40.710374
# 106                            Broad St       M      40.706476
# 278       Jamaica Center-Parsons/Archer       Q      40.702147
# 279  Sutphin Blvd-Archer Av-JFK Airport       Q      40.700486
#
#      GTFS Longitude  Census Tract  Census Tract Whole
# 79       -73.828294        144.00                 144
# 81       -73.844330         26.00                  26
# 82       -73.851576         20.00                  20
# 84       -73.867139          4.00                   4
# 86       -73.873785       1178.00                1178
# 87       -73.880039       1174.00                1174
# 89       -73.891688       1198.00                1198
# 90       -73.898654       1198.00                1198
# 91       -73.904512        405.00                 405
# 92       -73.910456        369.00                 369
# 94       -73.922270        397.00                 397
# 96       -73.935657        287.00                 287
# 100      -73.957757        529.00                 529
# 101      -73.987437         18.00                  18
# 102      -73.993915         18.00                  18
# 103      -73.999892         41.00                  41
# 104      -74.003401         29.01                  29
# 105      -74.007582         15.01                  15
# 106      -74.011056          7.00                   7
# 278      -73.801109        246.00                 246
# 279      -73.807969        208.00                 208

# %%
stations_expanded.value_counts('Daytime Routes')
# Out:
# Daytime Routes
# 2      49
# F      45
# R      45
# 5      45
# A      44
# C      40
# 1      38
# 6      38
# B      37
# D      36
# M      36
# 3      34
# J      30
# Q      29
# 4      28
# N      28
# L      24
# W      23
# 7      22
# E      22
# G      21
# SIR    21
# Z      21
# S      11
# Name: count, dtype: int64

# %%
len(stations_expanded['Daytime Routes'].unique())
# Out:
# 24
